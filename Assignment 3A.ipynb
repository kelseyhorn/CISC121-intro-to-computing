# %% [markdown]
# # Movie Streaming Studio

# %% [markdown]
# - practise in top down design
# - no implementation
# - decomposition into appropriate

# %%
Problem
- movie streaming service application to compete with netflix
- provide variety of movies that can be browsed, searched and viewed
- Keep track of the movies each user has watched and will use this
  this information to reccomend new movies 
- allow users to create and delete accounts and profiles
- be able to handle multiple users 

two groups of users: the paying customers that use your system and 
the administrators who take care of the system (employees)

1. when the user signs up: 
    1. provide name
    2. a unique username (needs to be checked for uniqueness)
    3. address
    4. email
    5. credit card number
    6. expiration date 
    7. password
should be able to update information anytime they are signed into
the application. Information will be stored in the database as the 
user profile 
- when a user signs in the username and password is checked against
the information found in the database to check for validity 
- integrate a 3rd party accounting system that will take care of 
monthly payments and provide information about payment history and 
account balances when requested by the user 
- administrators should be able to view user profiles, update user 
profiles and create and delete users as well as get the payment details
of history and account balance

Application 
- can browse by genre and search movie titles 
- look at movie details: genre, rating, length 
- select a movie to play and once its watched (all the way )mark as watched
  ;these should be put on the users watched list (stored for future reference)
- Movies on watched list should not appear when browsing by genre
- Movies should be displayed using a picture which are stored in a database

- user can ask for reccomendations of what movie to watch next
    - system should provide reccomendations based on the users watch history
    - could be another movie in the users most popular genre, rating, length, etc

Administrators
- be able to add movies, delete movies and update movie details 


try and draw out program first 
do not have to be specific about data types for the parameters and return values
think about the types of data that will be needed and returned 
do not need to specify a user interface module 

submit a single PDF
